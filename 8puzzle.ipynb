# %%
import heapq

MOVES = [(-1,0), (1,0), (0,-1), (0,1)]


def manhattan_distance(state, goal):
    distance = 0
    for i in range(3):
        for j in range(3):
            val = state[i][j]
            if val != 0:
                for x in range(3):
                    for y in range(3):
                        if goal[x][y] == val:
                            distance += abs(i - x) + abs(j - y)
    return distance


def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j



def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)

    for dx, dy in MOVES:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = [list(row) for row in state]
            moved_tile = new_state[nx][ny]
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append((tuple(tuple(row) for row in new_state), moved_tile))

    return neighbors


def a_star(start, goal):
    pq = []
    heapq.heappush(pq, (0, 0, start, []))
    visited = set()

    while pq:
        f, g, current, path = heapq.heappop(pq)

        if current == goal:
            return path + [(current, None)]

        if current in visited:
            continue

        visited.add(current)

        for neighbor, moved_tile in get_neighbors(current):
            if neighbor not in visited:
                h = manhattan_distance(neighbor, goal)
                heapq.heappush(
                    pq,
                    (g + 1 + h, g + 1, neighbor, path + [(current, moved_tile)])
                )
    return None


# ---------------- MAIN ----------------

print("Enter INITIAL state (use 0 for blank):")
initial = [list(map(int, input().split())) for _ in range(3)]

print("\nEnter GOAL state (use 0 for blank):")
goal = [list(map(int, input().split())) for _ in range(3)]

initial_state = tuple(tuple(row) for row in initial)
goal_state = tuple(tuple(row) for row in goal)

solution = a_star(initial_state, goal_state)

if solution:
    print("\nSolution Path:\n")
    for step in range(len(solution) - 1):
        state, moved = solution[step]
        print(f"Step {step + 1}: Moved tile {moved}")
        for row in state:
            print(row)
        print()

    print("Goal State Reached:")
    for row in goal_state:
        print(row)

    print("\nTotal number of moves:", len(solution) - 1)

else:
    print("No solution found.")
# Out:
# Enter INITIAL state (use 0 for blank):
#  1 2 3
#  4 0 6
#  7 5 8
# Enter GOAL state (use 0 for blank):
#  1 2 3
#  4 5 6
#  7 8 0
# Solution Path:
#
# Step 1: Moved tile 5
# (1, 2, 3)
# (4, 0, 6)
# (7, 5, 8)
#
# Step 2: Moved tile 8
# (1, 2, 3)
# (4, 5, 6)
# (7, 0, 8)
#
# Goal State Reached:
# (1, 2, 3)
# (4, 5, 6)
# (7, 8, 0)
#
# Total number of moves: 2
